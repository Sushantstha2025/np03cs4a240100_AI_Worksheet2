# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushantstha2025/np03cs4a240100_AI_Worksheet2/blob/main/Worksheet2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/datasets/Copy of bank.csv")
df1 = pd.DataFrame(data)

# obj_cols = df1.select_dtypes(include = "object").columns
# print(obj_cols)

# for col in obj_cols:
#   print(f"Unique value in {col}: ")
#   print(df1[col].unique())

# print(df1.isnull().sum())

obj_cols = df1.select_dtypes(include= "object").columns
df2 = df1.drop(columns=obj_cols)

df2.to_csv("banknumericdata.csv")

df2_read = pd.read_csv("banknumericdata.csv")
df2_read.describe()
# Out:
#          Unnamed: 0           age        balance           day      duration  \
# count  45211.000000  45211.000000   45211.000000  45211.000000  45211.000000
# mean   22605.000000     40.936210    1362.272058     15.806419    258.163080
# std    13051.435847     10.618762    3044.765829      8.322476    257.527812
# min        0.000000     18.000000   -8019.000000      1.000000      0.000000
# 25%    11302.500000     33.000000      72.000000      8.000000    103.000000
# 50%    22605.000000     39.000000     448.000000     16.000000    180.000000
# 75%    33907.500000     48.000000    1428.000000     21.000000    319.000000
# max    45210.000000     95.000000  102127.000000     31.000000   4918.000000
#
#            campaign         pdays      previous
# count  45211.000000  45211.000000  45211.000000
# mean       2.763841     40.197828      0.580323
# std        3.098021    100.128746      2.303441
# min        1.000000     -1.000000      0.000000
# ...

# %%
import pandas as pd
data = pd.read_csv("/content/drive/MyDrive/datasets/Copy of medical_students_dataset.csv")
df = pd.DataFrame(data)

df.info()

df_null = df.columns[df.isnull().any()]

print("null value list: ", list[df_null])

df["Student ID"] = df["Student ID"].ffill() + 1  # student id must be unique, hence increased the missing value with the value before it.
df["Age"] = df["Age"].fillna(df["Age"].median(), inplace=True)  # age is median as age may contain outliers that may make the central tendency skewed
df["Gender"] = df["Gender"].fillna("Unknown", inplace=True)  # some people might not be comfortable sharing their gender, hence written unknown
df["Height"] = df["Height"].fillna(df["Height"].mean(), inplace=True)  # mean chosen because less chance of outliers, hence normal skewness
df["Weight"] = df["Weight"].fillna(df["Weight"].mode()[0], inplace=True)  # mode chosen because it represents many people of the same weight. [0] given as mode can be of many values, so take the first mode.
df["Blood Type"] = df["Blood Type"].fillna(df["Blood Type"].mode()[0], inplace=True) # mode used to fill because max people have the same blood type.
df["BMI"] = df["BMI"].fillna(df["BMI"].median(), inplace=True)  # meadian chosen because there might contain outliers
df["Temperature"] = df["Temperature"].fillna(df["Temperature"].median(), inplace=True) # median chosen because some may be outliers
df["Heart Rate"] = df["Heart Rate"].fillna(df["Heart Rate"].mean(), inplace=True)  #mean chosen because heart rate of every person is average at most times
df["Cholestrol"] = df["Cholesterol"].fillna(df["Cholesterol"].mode()[0], inplace=True) # mode chosen because taking the most common approach
df["Diabetes"] = df["Diabetes"].fillna(df["Diabetes"].mode()[0], inplace=True) # median chosen because some people might be outliers
df["Smoking"] = df["Smoking"].fillna(df["Smoking"].mode()[0], inplace=True) # mode chosen because people either smoke or not and there is no such thing called average/half smoking

print(df.drop_duplicates())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Student ID      180000 non-null  float64
#  1   Age             180000 non-null  float64
#  2   Gender          180000 non-null  object
#  3   Height          180000 non-null  float64
#  4   Weight          180000 non-null  float64
#  5   Blood Type      180000 non-null  object
#  6   BMI             180000 non-null  float64
#  7   Temperature     180000 non-null  float64
#  8   Heart Rate      180000 non-null  float64
#  9   Blood Pressure  180000 non-null  float64
#  10  Cholesterol     180000 non-null  float64
#  11  Diabetes        180000 non-null  object
#  12  Smoking         180000 non-null  object
# dtypes: float64(9), object(4)
# memory usage: 19.8+ MB
# null value list:  list[Index(['Student ID', 'Age', 'Gender', 'Height', 'Weight', 'Blood Type', 'BMI',
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/drive/MyDrive/datasets/Copy of Titanic-Dataset.csv")
df = pd.DataFrame(data)
selected_df = df.loc[df["Pclass"]== 1, ["Name", "Pclass", "Sex", "Age", "Fare", "Survived"]]
fare_col = selected_df.loc[:, "Fare"]  # df.loc takes two arguments, row and column, row is given from first to last of Fare column
fare_col.describe()

null_df = df.loc[:, "Age"]
null_df.isna().sum()   # checking the number of null values
not_null_df = null_df[null_df.notna()]  # keep only rows that are not, null, since age is just a col, it is considered series. that is why, null_df.notna() rather than null_df[null_df["age"]]

embarked_dummies = pd.get_dummies(df["Embarked"], prefix="Embarked")
df = pd.concat([df, embarked_dummies], axis= 1)
# df.drop("Embarked", axis= 1, inplace=True)
print(df.head())

df_sex = df.groupby("Sex")
df_survived = df_sex["Survived"]
df_mean = df_survived.mean()

labels = df_mean.index
values = df_mean.values

plt.bar(labels, values, color=['pink', 'lightblue'])
plt.title("Mean Survival Rate by Gender")
plt.ylabel("Survival Rate")
plt.xlabel("Sex")
plt.ylim(0, 1) # survival rate ranges from 0 to 1

plt.show()


grouped = df.groupby(["Sex", "Embarked"])["Survived"].mean().unstack()  # group values of sex and embarked, and chose only the survived category and calculate mean of the survival rate and (unstack) convert embarked columns into separate columns such as embarked_c etc
grouped.plot(kind="bar", figsize=(10,6))  # pandas can directly plot the bar graph
plt.title("Mean Survival Rate by Sex and port of Embarktion")

plt.xlabel("Sex")
plt.ylabel("Mean Survival Rate")
plt.legend(title="Embarked")
plt.show()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  Embarked_C  Embarked_Q  \
# 0      0         A/5 21171   7.2500   NaN        S       False       False
# 1      0          PC 17599  71.2833   C85        C        True       False
# 2      0  STON/O2. 3101282   7.9250   NaN        S       False       False
# ...
